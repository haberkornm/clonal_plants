# %%
import pandas as pd

# %%
df = pd.read_csv('plant_features.csv', index_col = 0)

# %% [markdown]
# # Clonal features

# %%
stolon = ['Chloris virgata', 'Cynodon dactylon', 'Nitrophila occidentalis', 'Distichlis spicata', 'Hilaria belangeri', 
          'Hopia obtusa', 'Polypogon viridis', 'Anemopsis californica', 'Erigeron tracyi', 'Cyperus rotundus', 
          'Bothriochloa ischaemum', 'Bouteloua eriopoda', 'Bouteloua hirsuta', 'Leptochloa crinita', 'Scleropogon brevifolius', 
          'Cyperus esculentus', 'Bouteloua barbata', 'Nitrophila occidentalis', 'Eleocharis rostellata', 'Dactyloctenium aegyptium', 
          'Cyperus strigosus', 'Bothriochloa ischaemum', 'Leptochloa crinita']
rhizome = ['Trixis californica', 'Bouteloua trifida', 'Cynodon dactylon', 'Hilaria rigida', 'Pennisetum ciliare', 'Sorghum halepense', 
           'Tridens muticus', 'Rumex hymenosepalus', 'Artemisia ludoviciana', 'Nitrophila occidentalis', 'Arida carnosa', 'Artemisia dracunculus', 
           'Cyperus laevigatus', 'Cyperus mutisii', 'Bouteloua curtipendula', 'Distichlis spicata', 'Muhlenbergia dumosa', 'Phragmites australis', 
           'Tridens eragrostoides', 'Cyperus strigosus', 'Chaetopappa ericoides', 'Cyperus involucratus', 'Bouteloua eriopoda', 'Bouteloua gracilis', 
           'Digitaria insularis', 'Hilaria mutica', 'Chamaesaracha coronopus', 'Monardella arizonica', 'Solanum elaeagnifolium', 'Erigeron lobatus', 
           'Stephanomeria pauciflora', 'Cyperus esculentus', 'Hoffmannseggia glauca', 'Heliotropium curassavicum', 'Marsilea vestita', 
           'Notholaena californica', 'Notholaena standleyi', 'Typha domingensis', 'Acourtia nana', 'Artemisia ludoviciana', 'Stuckenia pectinata', 
           'Justicia longii', 'Nitrophila occidentalis', 'Arida carnosa', 'Artemisia dracunculus', 'Cyperus mutisii', 'Eleocharis rostellata', 
           'Schoenoplectus americanus', 'Juncus balticus', 'Juncus cooperi', 'Monardella arizonica', 'Bouteloua curtipendula', 'Distichlis spicata', 
           'Hopia obtusa', 'Muhlenbergia dumosa', 'Panicum antidotale', 'Phragmites australis', 'Tridens eragrostoides', 'Anemopsis californica', 
           'Symphyotrichum divaricatum', 'Veronica anagallis-aquatica', 'Arundo donax', 'Solanum elaeagnifolium', 'Chaetopappa ericoides', 
           'Bothriochloa ischaemum', 'Bouteloua eriopoda', 'Bouteloua gracilis', 'Digitaria insularis', 'Cheilanthes wootonii', 
           'Myriopteris lindheimeri', 'Myriopteris pringlei', 'Schoenoplectus pungens']

# %%
df['stolon'] = 0

for i in stolon:
    df.loc[df['Species name'] == i, 'stolon'] = 1

# %%
df['rhizome'] = 0

for i in rhizome:
    df.loc[df['Species name'] == i, 'rhizome'] = 1

# %%
['creeping', 'sucker', 'colonies']
# Out:
# ['creeping', 'sucker', 'colonies']

# %%
rooting = ['Euphorbia albomarginata', 'Echinochloa colona', 'Eriochloa aristata', 'Eriochloa acuminata', 'Erythranthe guttata', 
           'Poa annua', 'Glandularia bipinnatifida', 'Nasturtium officinale', 'Oxalis albicans', 'Bouteloua repens', 'Chamaesyce albomarginata', 
           'Melinis repens', 'Oxalis corniculata', 'Lophocereus schottii', 'Eragrostis lehmanniana', 'Commelina erecta', 'Melinis repens']

# %%
df[(df['VPAP'].notna()) & (df['VPAP'].str.contains("sucker"))][['Species name', 'lifeform', 'nativity_sw', 'low_elev_m', 'VPAP']].values
# Out:
# array([['Agave americana', 'succulent', 'native', 1.0,
#         'JANAS 32(1) Plant : perennial scapose herbs; Rosettes freely suckering, open, ca. 1-2 m tall, 2-3.7 m broad Leaves : numerous, 10-20 dm long, 1.5-2.5 dm wide, lanceolate, acuminate to abrubtly acuminate, narrowed above thickened base, rigid, plane or guttered or convex, light gray glaucous to light green, sometimes with cross-zoned or variegated patterns, the margins undulate to crenate to straight; teeth regular or variable, the larger ones 5-10 mm long, the smaller ones 3-5 mm long, straight or curved, 1-6 cm apart, brown to pruinose gray, interstitial teeth absent; terminal spine 2-5 cm long, conic to subulate, shallowly grooved above, shiny brown to pruinose gray INFLORESCENCE : with scape 5-9 m tall, open, of 15-35 long lateral horizontal branchlets in upper ½ of flowering stalk, the stalk thick, gray-green to glaucous Flowers : 70-100 mm long, long-pedicellate, fragrance unknown; tepals unequal, erect, thick, involute, pale yellow, the outer ones 25-38 mm long, thick linear-lanceolate, the apex sometimes red-tipped, the inner ones 2-3 mm shorter; filaments 60-90 mm long, inserted near mid-tube, light yellow, the anthers 30-36 mm long; ovary 30-45 mm long with constricted, grooved neck, green, the style 55-72 mm long when stigma is receptive, yellow; floral tube 8-20 mm long, 16-20 mm wide, deeply grooved, green Fruit : a loculicidal capsule, oblong to globose, 4-5 cm long, short-stipitate, short-beaked; SEEDS black, 7-8 mm long, 5-6 mm wide REFERENCES : Hodgson, Wendy. 1999. Agavaceae. Ariz. - Nev. Acad. Sci. 32(1).'],
#        ['Salix exigua', 'tree', 'native', 5.0,
#         'JANAS 29(1) Plant : Dioecious shrub or tree; 0.5-6 m tall, clonal by root suckers; branches gray-, red-, to yellow-brown, glabrous or tomentose becoming glabrous; branchlets glabrescent to hairy Leaves : stipules leaflike to absent; petioles glabrous or hairy, 1-9 mm long; proximal leaves on vegetative or flowering branchlets entire or gland-dotted; young leaves long silky; mature blade linear or ligulate, 30-160 mm long, 2-9 mm wide, 10-28(-37.5) times as long as wide, the lower surface glaucous or densely silky to silky-villous, the upper surface shiny, glabrescent or sparsely white villous to long silky, the base cuneate, the margins slightly revolute, remotely spinulose-serrulate or gland-dotted, with 1-5 teeth or glands per cm, the apex acuminate or acute INFLORESCENCE : cylindrical to subspherical catkins; coetaneous or serotinous; floral bracts tawny, 1.2-3.5 mm long, glabrous or hairy, the apices acute or rounded; pistillate floral bracts deciduous after flowering Flowers : STAMINATE FLOWERS densely flowered catkins 9-55 mm long; flowering branchlets 2-180 mm long; filaments hairy; nectaries 1 abaxial and 1 adaxial, slender or broad, 0.3-1.2 mm long. PISTILLATE FLOWERS in loosely flowered catkins 10-100 mm long; flowering branchlets 4-180 mm long; ovaries glabrous to sparsely silky; stigmas 0.28-0.72 long; styles 0-0.2 mm long; stipes 0.2-0.9 mm long; nectaries 1 adaxial, 1 or 0 abaxial, 0.5-2.7 mm long, shorter to longer than stipe Fruit : lanceolate or ovate Misc : Warm temperate; thickets along rivers, cienegas, and wet ditches; 350-2800 m (1100-8500 ft); Mar-Jun and throughout year REFERENCES : Argus, George W. 1995. SalicaceaePart 2. Salix. J. Ariz. - Nev. Acad. Sci. 29(1): 39']],
#       dtype=object)

# %% [markdown]
# # Clonal plant data

# %%
clones = pd.read_csv('Clones.csv')
clones = pd.DataFrame(clones[:118])
clones.rename(columns = {'Unnamed: 0' : 'Species name'}, inplace = True)

# %%
clones.columns
# Out:
# Index(['Species name', 'Life form', 'Life form.1', 'Root budding', 'Rhizome',
#        'Axial splitting', 'Creeping', 'Stolon', 'Bulb/corm', 'Stem budding',
#        'Multiple CGO', 'Disturbance related', 'Psuedo annual',
#        'Connection >2 years', 'Connection<2 years', 'Spread >0.5M',
#        'Spread<0.5M', 'Multiplication frequent', 'Multiplication infrequent',
#        'Genet >5 ramets', 'Genet <=5 ramets', 'CGO water storage',
#        'Descendents smaller', 'Descendents same size'],
#       dtype='object')

# %%
clones['Life form.1'].value_counts()
# Out:
# Life form.1
# grass         36
# shrub         35
# herbaceous    15
# subshrub      15
# succulent     12
# tree           5
# Name: count, dtype: int64

# %%
df.lifeform.value_counts()
# Out:
# lifeform
# herb          499
# grass         146
# subshrub       93
# shrub          75
# tree           42
# vine           39
# cactus         36
# pterophyte     21
# succulent      13
# parasite        1
# Name: count, dtype: int64

# %%
df[df.lifeform == 'grass'].Family.value_counts()
# Out:
# Family
# POACEAE       130
# CYPERACEAE     12
# JUNCACEAE       3
# TYPHACEAE       1
# Name: count, dtype: int64

# %%
clones[clones['Species name'].str.contains('Agave')]
# Out:
#        Species name  Life form Life form.1 Root budding Rhizome  \
# 106  Agave murpheyi        6.0   succulent            0       1
# 107   Agave deserti        6.0   succulent            0       1
#
#     Axial splitting Creeping Stolon Bulb/corm Stem budding  ...  \
# 106               0        0      0         0            1  ...
# 107               0        0      0         0            0  ...
#
#     Connection<2 years Spread >0.5M Spread<0.5M Multiplication frequent  \
# 106                  0            0           1                       1
# 107                  0            0           1                       1
#
#     Multiplication infrequent Genet >5 ramets Genet <=5 ramets  \
# 106                         0               1                0
# 107                         0               1                0
#
#     CGO water storage Descendents smaller Descendents same size
# 106                 1                   0                     1
# 107                 1                   0                     1
#
# [2 rows x 24 columns]
