# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('seinet_results.csv', index_col=0)
df.drop(columns = ['Unnamed: 0', 'seinet_status'], inplace = True)
print(df.shape)
print(df.columns)
# Out:
# (1057, 5)
# Index(['Genus', 'Species', 'FNA', 'VPAP', 'SW Field Guide'], dtype='object')

# %% [markdown]
# # Lifecycle duration

# %%
def extract_life_duration(text):
    """
    Extract plant life duration from descriptive text.

    Parameters
    ----------
    text : str or None

    Returns
    -------
    str
        One of:
        'annual', 'biennial', 'perennial',
        'annual/biennial', 'annual/perennial',
        'biennial/perennial', 'unknown'
    """
    if not text or not isinstance(text, str):
        return "unknown"

    t = text.lower()

    found = set()

    # strict word boundaries to avoid false matches
    patterns = {
        "annual": r"\bannual\b",
        "biennial": r"\bbiennial\b",
        "perennial": r"\bperennial\b"
    }

    for label, pattern in patterns.items():
        if re.search(pattern, t):
            found.add(label)

    if not found:
        return "unknown"

    # normalize combinations
    if found == {"annual"}:
        return "annual"
    if found == {"biennial"}:
        return "annual"
    if found == {"perennial"}:
        return "perennial"
    if found == {"annual", "biennial"}:
        return "annual"
    if found == {"annual", "perennial"}:
        return "annual/perennial"
    if found == {"biennial", "perennial"}:
        return "perennial"

    # rare but possible
    return "-".join(sorted(found))

# %%
df['duration_FNA'] = df["FNA"].apply(extract_life_duration)
df['duration_VPAP'] = df["VPAP"].apply(extract_life_duration)
df['duration_SWFG'] = df["SW Field Guide"].apply(extract_life_duration)

# %%
def consensus_life_duration(row):
    values = [
        row["duration_FNA"],
        row["duration_VPAP"],
        row["duration_SWFG"]
    ]
    values = [v for v in values if v != "unknown"]

    if not values:
        return "unknown"

    # if all agree
    if len(set(values)) == 1:
        return values[0]

    # otherwise keep ambiguity explicit
    return "/".join(sorted(set(values)))

# %%
df["duration_consensus"] = df.apply(consensus_life_duration, axis=1)

# %%
df.loc[df["duration_consensus"] == "annual/annual-biennial-perennial", "duration_consensus"] = "annual"
df.loc[df["duration_consensus"] == "annual-biennial-perennial/perennial", "duration_consensus"] = "perennial"
df.loc[df["duration_consensus"] == "annual-biennial-perennial", "duration_consensus"] = "annual"
df.loc[(df['Genus'] == 'Baileya') & (df['Species'] == 'multiradiata'), 'duration_consensus'] = "perennial"
df.loc[df["duration_consensus"] == "annual/perennial/perennial", "duration_consensus"] = "perennial"
df.loc[df["duration_consensus"] == "annual/annual/perennial", "duration_consensus"] = "annual"

# %%
df.loc[(df['Genus'] == 'Atriplex') & (df['Species'] == 'elegans'), 'duration_consensus'] = "annual"
df.loc[(df['Genus'] == 'Ambrosia') & (df['Species'] == 'confertiflora'), 'duration_consensus'] = "perennial"
df.loc[(df['Genus'] == 'Sonchus') & (df['Species'] == 'oleraceus'), 'duration_consensus'] = "annual"
df.loc[(df['Genus'] == 'Xanthisma') & (df['Species'] == 'spinulosum'), 'duration_consensus'] = "perennial"
df.loc[(df['Genus'] == 'Cryptantha') & (df['Species'] == 'holoptera'), 'duration_consensus'] = "perennial"
df.loc[(df['Genus'] == 'Cuscuta') & (df['Species'] == 'umbellata'), 'duration_consensus'] = "annual"
df.loc[(df['Genus'] == 'Chamaesyce') & (df['Species'] == 'pediculifera'), 'duration_consensus'] = "perennial"
df.loc[(df['Genus'] == 'Ditaxis') & (df['Species'] == 'neomexicana'), 'duration_consensus'] = "perennial"

# %%
lifespan = ['unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
            'annual', 'perennial', 'unknown', 'annual', 'perennial', 'annual', 'unknown', 'unknown', 'perennial', 'unknown', 
            'unknown', 'unknown', 'annual', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'perennial', 
            'unknown', 'unknown', 'unknown', 'unknown', 'annual', 'unknown', 'annual', 'annual', 'unknown', 'unknown', 
            'unknown', 'annual', 'annual', 'unknown', 'unknown', 'unknown', 'unknown', 'perennial', 'unknown', 
            'unknown', 'unknown', 'unknown', 'annual', 'annual', 'unknown']

# %%
for i, j in zip(df[df["duration_consensus"] == 'annual/perennial'][['Genus', 'Species']].values, lifespan):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'duration_consensus'] = j

# %%
lifespan2 = ['perennial', 'annual', 'perennial', 'annual', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 'annual', 
             'perennial', 'perennial', 'annual', 'perennial', 'annual', 'perennial', 'annual', 'perennial', 'perennial', 'annual', 
             'perennial', 'annual', 'perennial', 'annual', 'perennial', 'annual', 'perennial', 'annual', 'perennial', 'perennial']

# %%
for i, j in zip(df[(df.duration_consensus == 'unknown') & (df.duration_SWFG == 'annual/perennial')][['Genus', 'Species']].values, lifespan2):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'duration_consensus'] = j

# %%
lifespan3 = ['perennial', 'unknown',  'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'perennial', 'perennial', 'unknown', 'unknown', 'unknown', 'perennial', 'annual', 'perennial', 'unknown', 'unknown', 
             'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'perennial', 'perennial', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'perennial', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'unknown', 'unknown', 'unknown', 'unknown', 'perennial',  'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'unknown', 'annual', 'unknown', 'annual', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'perennial', 'unknown', 'perennial', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown']

# %%
for i, j in zip(df[df.duration_consensus == 'unknown'][['Genus', 'Species']].values, lifespan3):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'duration_consensus'] = j

# %%
lifespan4 = ['unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'annual', 'unknown', 'unknown', 
             'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'perennial', 'perennial', 'perennial', 'perennial', 'unknown', 'unknown', 'unknown', 'perennial', 'perennial', 'annual', 
             'unknown', 'unknown', 'unknown', 'unknown', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 
             'unknown', 'annual', 'unknown', 'unknown', 'unknown', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 
             'perennial', 'annual', 'unknown', 'annual', 'annual', 'annual', 'unknown', 'annual', 'perennial', 'perennial', 
             'unknown', 'unknown', 'unknown', 'annual', 'annual', 'annual', 'annual', 'perennial', 'unknown', 'unknown', 
             'unknown', 'unknown', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 'annual', 
             'unknown', 'perennial']

# %%
for i, j in zip(df[df.duration_consensus == 'unknown'][['Genus', 'Species']].values, lifespan4):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'duration_consensus'] = j

# %%
lifespan5 = ['perennial', 'annual', 'perennial', 'annual', 'annual', 'annual', 'perennial', 'annual', 'perennial', 'annual', 
             'unknown', 'perennial', 'annual', 'annual', 'annual', 'annual', 'perennial', 'annual', 'annual', 'perennial', 
             'perennial', 'annual', 'unknown', 'annual', 'annual', 'annual', 'perennial', 'annual', 'perennial', 'annual', 
             'perennial', 'perennial', 'perennial', 'annual', 'unknown', 'perennial', 'perennial', 'perennial', 'annual', 'annual']

# %%
for i, j in zip(df[df.duration_consensus == 'unknown'][['Genus', 'Species']].values, lifespan5):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'duration_consensus'] = j

# %%
df = df[df.duration_consensus != 'unknown'].reset_index(drop=True)

# %%
df.duration_consensus.value_counts()
# Out:
# duration_consensus
# perennial    579
# annual       475
# Name: count, dtype: int64

# %%
df.drop(columns = ['duration_FNA', 'duration_VPAP', 'duration_SWFG'], inplace = True)

# %% [markdown]
# # Native

# %%
NON_NATIVE_TERMS = [
    "non-native",
    "introduced",
    "invasive",
    "exotic",
    "naturalized", 
    "non native", 
    "not native"
]

def parse_nativity(sw_text):
    """
    Determine nativity from SW Field Guide text.

    Parameters
    ----------
    sw_text : str or None

    Returns
    -------
    str
        'native', 'non-native', or 'unknown'
    """

    if pd.isna(sw_text):
        return "unknown"

    text = sw_text.lower()

    # --- Explicit Nativity field ---
    nativity_match = re.search(
        r"nativity\s*:\s*([a-z\-]+)",
        text
    )
    
    if nativity_match:
        value = nativity_match.group(1)

        if value == "native":
            return "native"

        if value in NON_NATIVE_TERMS:
            return "non-native"

    # --- Fallback: search for non-native indicators anywhere ---
    for term in NON_NATIVE_TERMS:
        if re.search(rf"\b{term}\b", text):
            return "non-native"

    return "unknown"

# %%
NATIVITY_COLUMNS = ["FNA", "VPAP", "SW Field Guide"]

def nativity_consensus(row):
    results = []

    for col in NATIVITY_COLUMNS:
        value = parse_nativity(row[col])
        results.append(value)

    if "non-native" in results:
        return "non-native"

    if "native" in results:
        return "native"

    return "unknown"

# %%
df["nativity_sw"] = df.apply(nativity_consensus, axis=1)

# %%
df["nativity_sw"].value_counts()
# Out:
# nativity_sw
# native        760
# non-native    158
# unknown       136
# Name: count, dtype: int64

# %%
df[df["nativity_sw"] == 'unknown'].head(50)
# Out:
#               Genus        Species  \
# 18             Rhus       kearneyi
# 33    Triteleiopsis        palmeri
# 59         Diaperia          verna
# 74          Isocoma  coronopifolia
# 103   Stephanomeria       schottii
# 118      Cryptantha        ganderi
# 129         Lappula      redowskii
# 145        Tiquilia        palmeri
# 150   Dimorphocarpa    pinnatifida
# 157          Sibara      virginica
# 163       Carnegiea       gigantea
# 164  Cylindropuntia   acanthocarpa
# 165  Cylindropuntia      bigelovii
# 166  Cylindropuntia    echinocarpa
# 167  Cylindropuntia        fulgida
# 168  Cylindropuntia    leptocaulis
# 169  Cylindropuntia    ramosissima
# 171    Echinocactus   polycephalus
# 172    Echinocereus    engelmannii
# 173    Echinocereus       nicholii
# 174      Ferocactus   cylindraceus
# 175      Ferocactus         emoryi
# 176      Ferocactus      wislizeni
# 177        Grusonia         kunzei
# 178     Lophocereus       schottii
# 179     Mammillaria       grahamii
# 180     Mammillaria   tetrancistra
# 181         Opuntia      basilaris
# 182         Opuntia     chlorotica
# 183         Opuntia    engelmannii
# 184     Peniocereus        greggii
# 185     Stenocereus       thurberi
# 186          Celtis        pallida
# 188        Drymaria        viscosa
# 207          Croton      wigginsii
# 231           Lotus   salsuginosus
# 242    Psorothamnus         emoryi
# 264       Petalonyx       thurberi
# 278        Malvella   sagittifolia
# 283        Marsilea        vestita
# 290         Abronia   angustifolia
# 305      Camissonia    claviformis
# 306       Chylismia    claviformis
# 351         Festuca      octoflora
# 354         Hordeum        murinum
# 359         Panicum         alatum
# 376       Aliciella      latifolia
# 383       Linanthus        jonesii
# 385     Chorizanthe      corrugata
# 394      Nemacaulis       denudata
#
#                                                    FNA  \
# 18                                                 NaN
# 33   J. Chris Pires in Flora of North America (vol....
# 59   Theodore M. Barkley+, Luc Brouillet, John L. S...
# 74   Guy L. Nesom in Flora of North America (vol. 2...
# 103  L. D. Gottlieb in Flora of North America (vol....
# 118                                                NaN
# 129                                                NaN
# 145                                                NaN
# 150  Ihsan A. Al-Shehbaz in Flora of North America ...
# 157                                                NaN
# 163  Arthur C. Gibson in Flora of North America (vo...
# 164  Donald J. Pinkava in Flora of North America (v...
# 165  Donald J. Pinkava in Flora of North America (v...
# 166  Donald J. Pinkava in Flora of North America (v...
# 167  Donald J. Pinkava in Flora of North America (v...
# 168  Donald J. Pinkava in Flora of North America (v...
# 169  Donald J. Pinkava in Flora of North America (v...
# 171  Allan D. Zimmerman & Bruce D. Parfitt in Flora...
# 172  Allan D. Zimmerman & Bruce D. Parfitt in Flora...
# 173  Allan D. Zimmerman & Bruce D. Parfitt in Flora...
# 174  Allan D. Zimmerman & Bruce D. Parfitt in Flora...
# 175  Allan D. Zimmerman & Bruce D. Parfitt in Flora...
# 176  Allan D. Zimmerman & Bruce D. Parfitt in Flora...
# 177  Donald J. Pinkava in Flora of North America (v...
# 178  Arthur C. Gibson in Flora of North America (vo...
# 179  Bruce D. Parfitt & Arthur C. Gibson in Flora o...
# 180  Bruce D. Parfitt & Arthur C. Gibson in Flora o...
# 181  Donald J. Pinkava in Flora of North America (v...
# 182  Donald J. Pinkava in Flora of North America (v...
# 183  Donald J. Pinkava in Flora of North America (v...
# 184  Donald J. Pinkava in Flora of North America (v...
# 185  Bruce D. Parfitt & Arthur C. Gibson in Flora o...
# 186  Susan L. Sherman-Broyles, William T. Barker & ...
# 188  Ronald L. Hartman in Flora of North America (v...
# 207                                                NaN
# 231                                                NaN
# 242                                                NaN
# 264                                                NaN
# 278                                                NaN
# 283  David M. Johnson in Flora of North America (vo...
# 290  Leo A. Galloway in Flora of North America (vol...
# 305                                                NaN
# 306                                                NaN
# 351                                                NaN
# 354  Roland von Bothmer, Claus Baden, Niels H. Jaco...
# 359                                                NaN
# 376                                                NaN
# 383                                                NaN
# 385  James L. Reveal in Flora of North America (vol...
# 394  James L. Reveal in Flora of North America (vol...
#
#                                                   VPAP  \
# 18   CANOTIA 3(2) PLANT : Densely branched shrubs o...
# 33                                                 NaN
# 59                                                 NaN
# 74                                                 NaN
# 103                                                NaN
# 118                                                NaN
# 129                                                NaN
# 145                                                NaN
# 150                                                NaN
# 157                                                NaN
# 163  JANAS 29(1) Plant : Massive columnar trees to ...
# 164  JANAS 32(1) Plant : tree or shrub, sparsely to...
# 165  JANAS 32(1) Plant : small tree or shrub, much-...
# 166  JANAS 32(1) Plant : much-branched tree or shru...
# 167  JANAS 32(1) Plant : Tree 1-3 m tall, the trunk...
# 168  JANAS 32(1) Plant : Shrubs or small trees, spa...
# 169  JANAS 32(1) Plant : Tree or shrub, intricately...
# 171  JANAS 29(1) Plant : Barrel cactus with cluster...
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177  JANAS 32(1) Plant : Mat-forming shrub, much-br...
# 178  JANAS 29(1) Plant : Shrubs to 6.5 m tall. STEM...
# 179                                                NaN
# 180                                                NaN
# 181  JANAS 35(2) Plant : clump-forming shrub, 1-2(-...
# 182  JANAS 35(2) Plant : tree or shrub 2-2.5 m tall...
# 183  JANAS 35(2) Plant : tree or shrub, short trunk...
# 184  JANAS 29(1) Plant : Shrubs erect to sprawling,...
# 185  JANAS 29(1) Plant : Shrubs to 6 m tall. STEM m...
# 186  JANAS 35(2) Plant : large shrub; to 3 m tall, ...
# 188                                                NaN
# 207                                                NaN
# 231                                                NaN
# 242  CANOTIA 7(1) PLANT : Subshrub 0.3-1.0 m tall, ...
# 264  JANAS 30(2) Plant : shrub; to 2 m tall, often ...
# 278  JANAS 27(2) Plant : perennial herb; trailing s...
# 283  CANOTIA 5(1) PETIOLES : 1-35 cm long, glabrous...
# 290                                                NaN
# 305                                                NaN
# 306                                                NaN
# 351                                                NaN
# 354                                                NaN
# 359                                                NaN
# 376  CANOTIA (2005) PLANT : Annual, (4-)8-30 cm tal...
# 383  CANOTIA (2005) PLANT : Annual,4-10 cm tall, mu...
# 385                                                NaN
# 394                                                NaN
#
#                                         SW Field Guide duration_consensus  \
# 18                                                 NaN          perennial
# 33                                                 NaN          perennial
# 59                                                 NaN             annual
# 74                                                 NaN          perennial
# 103                                                NaN             annual
# 118                                                NaN             annual
# 129                                                NaN             annual
# 145                                                NaN          perennial
# 150                                                NaN             annual
# 157                                                NaN             annual
# 163  Benson 1969, Kearney and Peebles 1969 Common N...          perennial
# 164  Pinkava 1999, FNA 2003 Common Name : buck-horn...          perennial
# 165  Benson 1982, Pinkava 1999 Common Name : teddyb...          perennial
# 166  FNA 2004 Common Name : Wiggins' cholla Duratio...          perennial
# 167  Benson 1982, Pinkava 1999 Common Name : jumpin...          perennial
# 168  Benson 1969, Benson 1982, FNA 2003, Pinkava 19...          perennial
# 169  FNA 2004 Common Name : branched pencil cholla ...          perennial
# 171                                                NaN          perennial
# 172  Benson 1969, FNA 2003 Common Name : Engelmann'...          perennial
# 173  FNA 2004, Benson 1969 Common Name : Nichol's h...          perennial
# 174  FNA 2003 Common Name : California barrel cactu...          perennial
# 175  Common Name : Emory's barrel cactus Duration :...          perennial
# 176  Benson 1982, FNA 2003 Common Name : candy barr...          perennial
# 177  FNA 2003 Common Name : devil's cholla Duration...          perennial
# 178  FNA 2004, Pinkava 1995, Benson 1969 Common Nam...          perennial
# 179  Benson 1969, Benson 1982, FNA 2003 Common Name...          perennial
# 180  FNA 2004 Common Name : common fishhook cactus ...          perennial
# 181  Benson 1982, FNA 2003, Pinkava 2003 Common Nam...          perennial
# 182  Benson 1982, FNA 2003, Pinkava 2003 Common Nam...          perennial
# 183  Benson 1982, FNA 2003, Pinkava 2003 Common Nam...          perennial
# 184  Benson 1969, FNA 2006 Common Name : nightbloom...          perennial
# 185  FNA 2004, Pinkava 1995, Benson 1969 Common Nam...          perennial
# 186                                                NaN          perennial
# 188                                                NaN             annual
# 207                                                NaN          perennial
# 231                                                NaN             annual
# 242                                                NaN          perennial
# 264                                                NaN          perennial
# 278                                                NaN          perennial
# 283  FNA 1993, Yatskievych and Windham 2009, Kearne...          perennial
# 290                                                NaN             annual
# 305                                                NaN             annual
# 306                                                NaN             annual
# 351                                                NaN             annual
# 354                                                NaN             annual
# 359                                                NaN          perennial
# 376                                                NaN             annual
# 383                                                NaN             annual
# 385                                                NaN             annual
# 394                                                NaN             annual
#
#     nativity_sw
# 18      unknown
# 33      unknown
# 59      unknown
# 74      unknown
# 103     unknown
# 118     unknown
# 129     unknown
# 145     unknown
# 150     unknown
# 157     unknown
# 163     unknown
# 164     unknown
# 165     unknown
# 166     unknown
# 167     unknown
# 168     unknown
# 169     unknown
# 171     unknown
# 172     unknown
# 173     unknown
# 174     unknown
# 175     unknown
# 176     unknown
# 177     unknown
# 178     unknown
# 179     unknown
# 180     unknown
# 181     unknown
# 182     unknown
# 183     unknown
# 184     unknown
# 185     unknown
# 186     unknown
# 188     unknown
# 207     unknown
# 231     unknown
# 242     unknown
# 264     unknown
# 278     unknown
# 283     unknown
# 290     unknown
# 305     unknown
# 306     unknown
# 351     unknown
# 354     unknown
# 359     unknown
# 376     unknown
# 383     unknown
# 385     unknown
# 394     unknown

# %% [markdown]
# # Elevation

# %% [markdown]
# # Aquatic

# %% [markdown]
# # Lifeform
