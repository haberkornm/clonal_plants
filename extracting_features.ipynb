# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('seinet_results.csv', index_col=0)
df.drop(columns = ['Unnamed: 0', 'seinet_status'], inplace = True)
print(df.shape)
print(df.columns)
# Out:
# (1057, 5)
# Index(['Genus', 'Species', 'FNA', 'VPAP', 'SW Field Guide'], dtype='object')

# %%
df['Species name'] = df.Genus + ' ' + df.Species

# %%
plant_list = pd.read_csv('master_plant_list.csv', index_col=0)

# %%
df = df.merge(plant_list, left_on = 'Species name', right_on = 'Species', how = 'left')
df.drop(columns = 'Species_y', inplace = True)
df.rename(columns = {'Species_x' : 'Species'}, inplace = True)
df.head()
# Out:
#               Genus         Species  \
# 0     Carlowrightia       arizonica
# 1          Justicia     californica
# 2  Mesembryanthemum      nodiflorum
# 3        Trianthema  portulacastrum
# 4        Amaranthus       crassipes
#
#                                                  FNA VPAP  \
# 0                                                NaN  NaN
# 1                                                NaN  NaN
# 2  Nancy J. Vivrette, John E. Bleck & Wayne R. Fe...  NaN
# 3  Wayne R. Ferren Jr. in Flora of North America ...  NaN
# 4  Sergei L. Mosyakin & Kenneth R. Robertson in F...  NaN
#
#                                       SW Field Guide  \
# 0  Wiggins 1964, Daniel 1984, Kearney and Peebles...
# 1  Benson and Darrow 1981, Hickman 1993, Powell 1...
# 2  FNA 2004 Duration : Annual Nativity : Non-Nati...
# 3  Kearney and Peebles 1969, FNA 2004, Correll an...
# 4                                                NaN
#
#                   Species name         Family
# 0      Carlowrightia arizonica    ACANTHACEAE
# 1         Justicia californica    ACANTHACEAE
# 2  Mesembryanthemum nodiflorum      AIZOACEAE
# 3    Trianthema portulacastrum      AIZOACEAE
# 4         Amaranthus crassipes  AMARANTHACEAE

# %% [markdown]
# # Lifecycle duration

# %%
def extract_life_duration(text):
    """
    Extract plant life duration from descriptive text.

    Parameters
    ----------
    text : str or None

    Returns
    -------
    str
        One of:
        'annual', 'biennial', 'perennial',
        'annual/biennial', 'annual/perennial',
        'biennial/perennial', 'unknown'
    """
    if not text or not isinstance(text, str):
        return "unknown"

    t = text.lower()

    found = set()

    # strict word boundaries to avoid false matches
    patterns = {
        "annual": r"\bannual\b",
        "biennial": r"\bbiennial\b",
        "perennial": r"\bperennial\b"
    }

    for label, pattern in patterns.items():
        if re.search(pattern, t):
            found.add(label)

    if not found:
        return "unknown"

    # normalize combinations
    if found == {"annual"}:
        return "annual"
    if found == {"biennial"}:
        return "annual"
    if found == {"perennial"}:
        return "perennial"
    if found == {"annual", "biennial"}:
        return "annual"
    if found == {"annual", "perennial"}:
        return "annual/perennial"
    if found == {"biennial", "perennial"}:
        return "perennial"

    # rare but possible
    return "-".join(sorted(found))

# %%
df['duration_FNA'] = df["FNA"].apply(extract_life_duration)
df['duration_VPAP'] = df["VPAP"].apply(extract_life_duration)
df['duration_SWFG'] = df["SW Field Guide"].apply(extract_life_duration)

# %%
def consensus_life_duration(row):
    values = [
        row["duration_FNA"],
        row["duration_VPAP"],
        row["duration_SWFG"]
    ]
    values = [v for v in values if v != "unknown"]

    if not values:
        return "unknown"

    # if all agree
    if len(set(values)) == 1:
        return values[0]

    # otherwise keep ambiguity explicit
    return "/".join(sorted(set(values)))

# %%
df["duration_consensus"] = df.apply(consensus_life_duration, axis=1)

# %%
df.loc[df["duration_consensus"] == "annual/annual-biennial-perennial", "duration_consensus"] = "annual"
df.loc[df["duration_consensus"] == "annual-biennial-perennial/perennial", "duration_consensus"] = "perennial"
df.loc[df["duration_consensus"] == "annual-biennial-perennial", "duration_consensus"] = "annual"
df.loc[(df['Genus'] == 'Baileya') & (df['Species'] == 'multiradiata'), 'duration_consensus'] = "perennial"
df.loc[df["duration_consensus"] == "annual/perennial/perennial", "duration_consensus"] = "perennial"
df.loc[df["duration_consensus"] == "annual/annual/perennial", "duration_consensus"] = "annual"

# %%
df.loc[(df['Genus'] == 'Atriplex') & (df['Species'] == 'elegans'), 'duration_consensus'] = "annual"
df.loc[(df['Genus'] == 'Ambrosia') & (df['Species'] == 'confertiflora'), 'duration_consensus'] = "perennial"
df.loc[(df['Genus'] == 'Sonchus') & (df['Species'] == 'oleraceus'), 'duration_consensus'] = "annual"
df.loc[(df['Genus'] == 'Xanthisma') & (df['Species'] == 'spinulosum'), 'duration_consensus'] = "perennial"
df.loc[(df['Genus'] == 'Cryptantha') & (df['Species'] == 'holoptera'), 'duration_consensus'] = "perennial"
df.loc[(df['Genus'] == 'Cuscuta') & (df['Species'] == 'umbellata'), 'duration_consensus'] = "annual"
df.loc[(df['Genus'] == 'Chamaesyce') & (df['Species'] == 'pediculifera'), 'duration_consensus'] = "perennial"
df.loc[(df['Genus'] == 'Ditaxis') & (df['Species'] == 'neomexicana'), 'duration_consensus'] = "perennial"

# %%
lifespan = ['unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
            'annual', 'perennial', 'unknown', 'annual', 'perennial', 'annual', 'unknown', 'unknown', 'perennial', 'unknown', 
            'unknown', 'unknown', 'annual', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'perennial', 
            'unknown', 'unknown', 'unknown', 'unknown', 'annual', 'unknown', 'annual', 'annual', 'unknown', 'unknown', 
            'unknown', 'annual', 'annual', 'unknown', 'unknown', 'unknown', 'unknown', 'perennial', 'unknown', 
            'unknown', 'unknown', 'unknown', 'annual', 'annual', 'unknown']

# %%
for i, j in zip(df[df["duration_consensus"] == 'annual/perennial'][['Genus', 'Species']].values, lifespan):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'duration_consensus'] = j

# %%
lifespan2 = ['perennial', 'annual', 'perennial', 'annual', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 'annual', 
             'perennial', 'perennial', 'annual', 'perennial', 'annual', 'perennial', 'annual', 'perennial', 'perennial', 'annual', 
             'perennial', 'annual', 'perennial', 'annual', 'perennial', 'annual', 'perennial', 'annual', 'perennial', 'perennial']

# %%
for i, j in zip(df[(df.duration_consensus == 'unknown') & (df.duration_SWFG == 'annual/perennial')][['Genus', 'Species']].values, lifespan2):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'duration_consensus'] = j

# %%
lifespan3 = ['perennial', 'unknown',  'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'perennial', 'perennial', 'unknown', 'unknown', 'unknown', 'perennial', 'annual', 'perennial', 'unknown', 'unknown', 
             'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'perennial', 'perennial', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'perennial', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'unknown', 'unknown', 'unknown', 'unknown', 'perennial',  'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'unknown', 'annual', 'unknown', 'annual', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'perennial', 'unknown', 'perennial', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown']

# %%
for i, j in zip(df[df.duration_consensus == 'unknown'][['Genus', 'Species']].values, lifespan3):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'duration_consensus'] = j

# %%
lifespan4 = ['unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'annual', 'unknown', 'unknown', 
             'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 
             'perennial', 'perennial', 'perennial', 'perennial', 'unknown', 'unknown', 'unknown', 'perennial', 'perennial', 'annual', 
             'unknown', 'unknown', 'unknown', 'unknown', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 
             'unknown', 'annual', 'unknown', 'unknown', 'unknown', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 
             'perennial', 'annual', 'unknown', 'annual', 'annual', 'annual', 'unknown', 'annual', 'perennial', 'perennial', 
             'unknown', 'unknown', 'unknown', 'annual', 'annual', 'annual', 'annual', 'perennial', 'unknown', 'unknown', 
             'unknown', 'unknown', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 'perennial', 'annual', 
             'unknown', 'perennial']

# %%
for i, j in zip(df[df.duration_consensus == 'unknown'][['Genus', 'Species']].values, lifespan4):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'duration_consensus'] = j

# %%
lifespan5 = ['perennial', 'annual', 'perennial', 'annual', 'annual', 'annual', 'perennial', 'annual', 'perennial', 'annual', 
             'unknown', 'perennial', 'annual', 'annual', 'annual', 'annual', 'perennial', 'annual', 'annual', 'perennial', 
             'perennial', 'annual', 'unknown', 'annual', 'annual', 'annual', 'perennial', 'annual', 'perennial', 'annual', 
             'perennial', 'perennial', 'perennial', 'annual', 'unknown', 'perennial', 'perennial', 'perennial', 'annual', 'annual']

# %%
for i, j in zip(df[df.duration_consensus == 'unknown'][['Genus', 'Species']].values, lifespan5):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'duration_consensus'] = j

# %%
df = df[df.duration_consensus != 'unknown'].reset_index(drop=True)

# %%
df.duration_consensus.value_counts()
# Out:
# duration_consensus
# perennial    579
# annual       475
# Name: count, dtype: int64

# %%
df.drop(columns = ['duration_FNA', 'duration_VPAP', 'duration_SWFG'], inplace = True)

# %% [markdown]
# # Native

# %%
NON_NATIVE_TERMS = [
    "non-native",
    "introduced",
    "invasive",
    "exotic",
    "naturalized", 
    "non native", 
    "not native"
]

def parse_nativity(sw_text):
    """
    Determine nativity from SW Field Guide text.

    Parameters
    ----------
    sw_text : str or None

    Returns
    -------
    str
        'native', 'non-native', or 'unknown'
    """

    if pd.isna(sw_text):
        return "unknown"

    text = sw_text.lower()

    # --- Explicit Nativity field ---
    nativity_match = re.search(
        r"nativity\s*:\s*([a-z\-]+)",
        text
    )
    
    if nativity_match:
        value = nativity_match.group(1)

        if value == "native":
            return "native"

        if value in NON_NATIVE_TERMS:
            return "non-native"

    # --- Fallback: search for non-native indicators anywhere ---
    for term in NON_NATIVE_TERMS:
        if re.search(rf"\b{term}\b", text):
            return "non-native"

    return "unknown"

# %%
NATIVITY_COLUMNS = ["FNA", "VPAP", "SW Field Guide"]

def nativity_consensus(row):
    results = []

    for col in NATIVITY_COLUMNS:
        value = parse_nativity(row[col])
        results.append(value)

    if "non-native" in results:
        return "non-native"

    if "native" in results:
        return "native"

    return "unknown"

# %%
df["nativity_sw"] = df.apply(nativity_consensus, axis=1)

# %%
df.loc[(df.Family == 'CACTACEAE') & (df.nativity_sw == 'unknown'), 'nativity_sw'] = 'native'

# %%
df.drop(df[(df.Genus == 'Festuca') & (df.Species == 'octoflora')].index, inplace = True)

# %%
df.loc[(df.Family == 'ASPARAGACEAE') & (df.nativity_sw == 'unknown'), 'nativity_sw'] = 'native'

# %%
df.loc[(df.Family == 'PTERIDACEAE') & (df.nativity_sw == 'unknown'), 'nativity_sw'] = 'native'

# %%
df.drop(df[df.Species == 'wootoni'].index, inplace=True)

# %%
df.drop(df[df['Species name'] == 'Cheilanthes yavapensis'].index, inplace = True)

# %%
df.loc[df['Species name'] == 'Hordeum arizonicum', 'nativity_sw'] = 'native'
df.loc[df['Species name'] == 'Hordeum murinum', 'nativity_sw'] = 'non-native'
df.loc[df['Species name'] == 'Rhus kearneyi', 'nativity_sw'] = 'native'
df.loc[df['Species name'] == 'Diaperia verna', 'nativity_sw'] = 'native'
df.loc[df['Species name'] == 'Isocoma coronopifolia', 'nativity_sw'] = 'native'
df.loc[df['Species name'] == 'Stephanomeria schottii', 'nativity_sw'] = 'native'
df.loc[df['Species name'] == 'Cryptantha ganderi', 'nativity_sw'] = 'native'

# %%
nativity = ['unknown', 'unknown', 'native', 'unknown', 'native', 'native', 'unknown', 'unknown', 'unknown', 'unknown', 
            'unknown', 'native', 'native', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'native', 'native', 
            'native', 'native', 'unknown', 'unknown', 'unknown', 'native', 'native', 'native', 'native', 'native', 
            'native', 'unknown', 'unknown', 'native', 'non-native', 'unknown', 'unknown', 'native', 'unknown', 'native', 
            'native', 'unknown', 'unknown', 'unknown', 'unknown', 'native', 'unknown', 'unknown', 'native', 'unknown', 
            'native', 'native', 'unknown', 'unknown', 'unknown', 'unknown', 'native', 'native', 'unknown', 'unknown', 
            'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'native', 'native', 'unknown']

# %%
for i, j in zip(df[df.nativity_sw == 'unknown'][['Genus', 'Species']].values, nativity):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'nativity_sw'] = j

# %%
nativity2 = ['unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'native', 'native', 'native', 'unknown', 'unknown', 
             'unknown', 'native', 'native', 'unknown', 'unknown', 'unknown', 'unknown', 'unknown', 'native', 'native', 
             'native', 'unknown', 'unknown', 'unknown', 'native', 'unknown', 'unknown', 'unknown', 'unknown', 'native', 
             'unknown', 'non-native', 'unknown', 'native', 'native', 'unknown', 'unknown', 'unknown', 'native', 'unknown', 
             'unknown']

# %%
for i, j in zip(df[df.nativity_sw == 'unknown'][['Genus', 'Species']].values, nativity2):
    df.loc[(df['Genus'] == i[0]) & (df['Species'] == i[1]), 'nativity_sw'] = j

# %%
df.loc[df.nativity_sw == 'unknown', 'nativity_sw'] = 'native'

# %%
df.loc[df['Species name'] == 'Ricinus communis', 'nativity_sw'] = 'non-native'

# %%
df.loc[df['Species name'] == 'Urochloa reptans', 'nativity_sw'] = 'non-native'

# %%
df.loc[df['Species name'] == 'Melia azedarach', 'nativity_sw'] = 'non-native'

# %%
df["nativity_sw"].value_counts()
# Out:
# nativity_sw
# native        887
# non-native    164
# Name: count, dtype: int64

# %% [markdown]
# # Aquatic

# %% [raw]
# import requests
# from bs4 import BeautifulSoup
#
# url = "https://www.wildflower.org/collections/printable.php?collection=nwpl"
#
# # Use realistic headers so the server doesn’t block you
# headers = {
#     "User-Agent": (
#         "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
#         "AppleWebKit/537.36 (KHTML, like Gecko) "
#         "Chrome/120.0.0.0 Safari/537.36"
#     ),
#     "Referer": "https://www.wildflower.org/collections/"
# }
#
# response = requests.get(url, headers=headers, timeout=30)
# response.raise_for_status()
#
# soup = BeautifulSoup(response.text, "html.parser")
#
# table = soup.find("table")
#
# nwl_df = pd.read_html(str(table))[0]

# %% [raw]
# nwl_df.drop(0, inplace = True)
# headers = nwl_df.loc[1].values
# nwl_df.drop(1, inplace = True)
# nwl_df.columns = headers
#
# nwl_df = nwl_df.map(lambda x: x.strip() if isinstance(x, str) else x)
# nwl_df = nwl_df[~nwl_df['Scientific Name'].isna()].reset_index(drop=True)
#
# nwl_df.to_csv('plant_lists/national_wetland_plant_list.csv')

# %%
nwl_df = pd.read_csv(r'plant_lists/national_wetland_plant_list.csv', index_col = 0)
nwl_df.shape
# Out:
# (2966, 6)

# %%
nwl_df.sample(5)
# Out:
#             Scientific Name               Common Name   Duration     Habit  \
# 1483    Lobelia siphilitica        Great Blue Lobelia  Perennial      Herb
# 2616  Stellaria crassifolia           Fleshy Starwort  Perennial      Herb
# 76         Allium tricoccum           Wild Leek, Ramp  Perennial      Herb
# 2249          Rubus pedatus  Strawberryleaf Raspberry  Perennial  Subshrub
# 1582       Meehania cordata             Meehan's Mint  Perennial      Herb
#
#                          Sun       Water
# 1483  Sun, Shade, Part-shade  Wet, Moist
# 2616                     NaN         NaN
# 76                     Shade       Moist
# 2249  Sun, Shade, Part-shade  Moist, Dry
# 1582                     NaN         NaN

# %%
nwl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2966 entries, 0 to 2965
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Scientific Name  2966 non-null   object
#  1   Common Name      2966 non-null   object
#  2   Duration         2965 non-null   object
#  3   Habit            2965 non-null   object
#  4   Sun              1701 non-null   object
#  5   Water            1415 non-null   object
# dtypes: object(6)
# memory usage: 162.2+ KB

# %%
df = df.merge(nwl_df[['Scientific Name', 'Habit']], left_on = 'Species name', right_on = 'Scientific Name', how = 'left')

# %%
df['aquatic'] = df["Scientific Name"].notna().astype(int)
df.drop(columns = ['Scientific Name', 'Habit'], inplace = True)

# %%
df.loc[df.Genus == 'Populus', 'aquatic'] = 1
df.loc[df.Genus == 'Prosopis', 'aquatic'] = 0
df.loc[df.Genus == 'Dichelostemma', 'aquatic'] = 0
df.loc[df.Genus == 'Lycium', 'aquatic'] = 0
df.loc[df.Genus == 'Agave', 'aquatic'] = 0
df.loc[df.Genus == 'Tamarix', 'aquatic'] = 1
df.loc[df['Species name'] == 'Celtis reticulata', 'aquatic'] = 1
df.loc[df.Family == 'CYPERACEAE', 'aquatic'] = 1
df.loc[df.Genus == 'Najas', 'aquatic'] = 1
df.loc[df.Genus == 'Nasturtium', 'aquatic'] = 1

# %%
df.aquatic.value_counts()
# Out:
# aquatic
# 0    923
# 1    128
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Genus', 'Species', 'FNA', 'VPAP', 'SW Field Guide', 'Species name',
#        'Family', 'duration_consensus', 'nativity_sw', 'aquatic'],
#       dtype='object')

# %% [markdown]
# # Lifeform

# %%
LIFEFORMS = {"grass", "herb", "subshrub", "shrub", "tree", "vine", "cactus", "succulent", "bryophyte", "pterophyte"}

# %%
FAMILY_LIFEFORMS = {
    # Grasses
    "Poaceae": "grass",
    "Cyperaceae": "grass",
    "Juncaceae": "grass",

    # Succulents
    "Crassulaceae": "succulent",
    "Agavaceae": "succulent",

    # Cactus
    "Cactaceae": "cactus",

    # Bryophytes
    "Bryaceae": "bryophyte",
    "Sphagnaceae": "bryophyte",

    # Ferns
    "Pteridaceae": "pterophyte",
    "Dryopteridaceae": "pterophyte",
    "Polypodiaceae": "pterophyte"
}

# %%
def normalize_family(family):
    if pd.isna(family):
        return None

    family = family.strip()
    family = re.split(r"[ (;]", family)[0]  # remove annotations
    family = family.capitalize()

    return family

# %%
def lifeform_from_family(family):
    family = normalize_family(family)
    return FAMILY_LIFEFORMS.get(family)

# %%
LIFEFORM_KEYWORDS = {
    "tree": [" tree", " trees"],
    "shrub": [" shrub", " shrubs"],
    "subshrub": [" subshrub"],
    "herb": [" herb", " herbs", " forb", " forbs", " woody herb"],
    "grass": [" grass", " grasses"],
    "vine": [" vine", " climbing", " twining", " liana"],
    "cactus": [" cactus", " cacti"],
    "succulent": [" succulent", " fleshy"],
    "bryophyte": [" moss", " liverwort"],
    "pterophyte": [" fern", " ferns", " frond"]
}

# %%
def extract_lifeforms_from_text(text):
    if pd.isna(text):
        return set()

    text = text.lower()
    found = set()

    for lf, patterns in LIFEFORM_KEYWORDS.items():
        if any(p in text for p in patterns):
            found.add(lf)

    return found

# %%
def resolve_lifeform_conflicts(lifeforms):
    lf = set(lifeforms)

    if "tree" in lf and "shrub" in lf:
        return "tree"

    if "cactus" in lf and "succulent" in lf:
        return "cactus"

    if "herb" in lf and "woody herb" in lf:
        return "herb"

    if "vine" in lf and "shrub" in lf:
        return "vine"

    if len(lf) == 1:
        return next(iter(lf))

    if len(lf) > 1:
        # fallback priority
        priority = [
            "tree", "shrub", "subshrub", "vine",
            "grass", "herb", "succulent",
            "cactus", "pterophyte", "bryophyte"
        ]
        for p in priority:
            if p in lf:
                return p

    return None

# %%
def lifeform_from_text_sources(row):
    combined = " ".join([
        str(row.get("FNA", "")),
        str(row.get("VPAP", "")),
        str(row.get("SW Field Guide", ""))
    ])

    lifeforms = extract_lifeforms_from_text(combined)
    return resolve_lifeform_conflicts(lifeforms)

# %%
def determine_lifeform(row):
    # 1️⃣ Family override (final answer)
    family_lf = lifeform_from_family(row["Family"])
    if family_lf is not None:
        return family_lf

    # 2️⃣ Text-based inference
    return lifeform_from_text_sources(row)

# %%
df["lifeform"] = df.apply(determine_lifeform, axis=1)

# %%
df.loc[(df.lifeform == 'grass') & (df.Family == 'BRASSICACEAE'), 'lifeform'] = 'herb'

# %%
brassica = ['herb', 'herb', 'subshrub', 'herb', 'herb', 'herb']
for i,j in zip(df[(df.Family == 'BRASSICACEAE') & (df.lifeform == 'shrub')]['Species name'], brassica):
    df.loc[df['Species name'] == i, 'lifeform'] = j

# %%
df.drop(df[df['Species name'] == 'Arabis perennans'].index, inplace = True)
df.loc[(df.Family == 'BRASSICACEAE') & (df.lifeform == 'vine'), 'lifeform'] = 'herb'
df.loc[(df.Family == 'BRASSICACEAE') & (df.lifeform == 'succulent'), 'lifeform'] = 'herb'
df.loc[df['Species name'] == 'Cannabis sativa', 'lifeform'] = 'herb'
df.loc[(df.duration_consensus == 'annual') & (df.lifeform == 'grass') & (df.Family == 'ASTERACEAE'), 'lifeform'] = 'herb'
df.loc[(df.duration_consensus == 'annual') & (df.lifeform == 'grass') & (~df.Family.isin(['POACEAE', 'CYPERACEAE', 'JUNCACEAE'])), 'lifeform'] = 'herb'
df.loc[(df.duration_consensus == 'annual') & (df.lifeform == 'tree'), 'lifeform'] = 'herb'
df.loc[(df.duration_consensus == 'annual') & (df.lifeform == 'shrub'), 'lifeform'] = 'herb'

# %%
ann_subshrub = ['herb', 'herb', 'herb', 'herb', 'subshrub', 'herb', 'subshrub', 'herb', 'herb', 'subshrub', 'subshrub', 'herb']
for i,j in zip(df.loc[(df.duration_consensus == 'annual') & (df.lifeform == 'subshrub'), 'Species name'], ann_subshrub):
    df.loc[df['Species name'] == i, 'lifeform'] = j

# %%
df.drop(df[df['Species name'] == 'Ipomoea hederacea'].index, inplace = True)
df.loc[df.Genus == 'Agave', 'lifeform'] = 'succulent'
df.loc[df.Family == 'SELAGINELLACEAE', 'lifeform'] = 'pterophyte'
df.loc[df.Genus == 'Yucca', 'lifeform'] = 'succulent'
df.loc[(df.lifeform == 'grass') & (~df.Family.isin(['POACEAE', 'CYPERACEAE', 'JUNCACEAE'])), 'lifeform'] = 'herb'

# %%
shrubs = ['subshrub', 'shrub',  'shrub', 'shrub', 'shrub', 'shrub', 'subshrub', 'subshrub', 'subshrub', 'subshrub', 
          'subshrub', 'subshrub', 'subshrub', 'subshrub', 'subshrub', 'shrub', 'shrub', 'subshrub', 'subshrub', 'subshrub', 
          'subshrub', 'subshrub', 'shrub', 'subshrub', 'subshrub', 'subshrub', 'shrub', 'subshrub', 'subshrub', 'subshrub', 
          'subshrub', 'subshrub', 'subshrub', 'subshrub', 'shrub', 'shrub', 'shrub', 'shrub', 'herb', 'shrub', 
          'shrub', 'subshrub', 'subshrub', 'subshrub', 'shrub', 'subshrub', 'shrub', 'shrub', 'subshrub', 'subshrub', 
          'subshrub', 'subshrub', 'subshrub', 'subshrub', 'herb', 'subshrub', 'subshrub', 'subshrub', 'shrub', 'shrub', 
          'subshrub', 'subshrub', 'shrub', 'shrub', 'shrub', 'shrub', 'subshrub', 'shrub', 'shrub', 'shrub', 
          'shrub', 'shrub', 'shrub', 'shrub', 'shrub', 'subshrub', 'herb', 'shrub', 'subshrub', 'subshrub', 
          'subshrub', 'subshrub', 'subshrub', 'shrub', 'subshrub', 'shrub', 'shrub', 'shrub', 'shrub', 'subshrub', 
          'subshrub', 'subshrub', 'herb', 'subshrub', 'subshrub', 'herb', 'shrub', 'shrub', 'shrub', 'shrub', 
          'shrub', 'herb', 'shrub', 'subshrub', 'subshrub', 'subshrub', 'subshrub', 'shrub', 'herb', 'shrub', 
          'subshrub', 'subshrub', 'herb', 'succulent', 'subshrub', 'subshrub', 'subshrub', 'herb', 'shrub', 'shrub', 
          'subshrub', 'shrub', 'subshrub', 'shrub', 'shrub', 'subshrub', 'subshrub', 'shrub', 'herb', 'shrub']
shrub_species = df[df.lifeform == 'shrub']['Species name']

# %%
for i, j in zip(shrub_species, shrubs):
    df.loc[df['Species name'] == i, 'lifeform'] = j

# %%
subshrubs = ['subshrub', 'subshrub', 'subshrub', 'subshrub', 'subshrub', 'subshrub', 'subshrub', 'subshrub', 'subshrub', 'subshrub',
             'subshrub', 'subshrub', 'subshrub', 'herb', 'subshrub', 'herb', 'herb', 'subshrub', 'subshrub', 'subshrub', 
             'subshrub', 'herb', 'herb', 'herb', 'subshrub', 'subshrub', 'herb', 'herb', 'herb', 'subshrub', 
             'subshrub', 'shrub', 'herb', 'subshrub', 'subshrub', 'subshrub', 'herb', 'subshrub', 'herb', 'herb', 
             'herb', 'herb', 'subshrub', 'herb', 'herb', 'herb', 'subshrub', 'herb', 'herb', 'herb', 
             'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'subshrub', 'herb','herb', 
             'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'subshrub', 'herb', 'subshrub', 
             'subshrub']

# %%
for i, j in zip(df.loc[(~df['Species name'].isin(shrub_species)) & (df.lifeform == 'subshrub')]['Species name'], subshrubs):
    df.loc[(df['Species name'] == i), 'lifeform'] = j

# %%
df.loc[df['Species name'] == 'Cylindropuntia spinosior', 'nativity_sw'] = 'native'

# %%
df.loc[df.Genus == 'Nolina', 'lifeform'] = 'succulent'

# %%
df.drop(df[df['Species name'] == 'Acacia greggii'].index, inplace = True)

# %%
df.reset_index(drop = True, inplace = True)

# %%
trees = ['shrub', 'shrub', 'tree', 'tree', 'tree', 'tree', 'tree', 'tree', 'tree', 'tree', 
         'tree', 'tree', 'tree', 'shrub', 'tree', 'shrub', 'shrub', 'parasite', 'tree', 'shrub', 
         'shrub', 'shrub', 'shrub', 'shrub', 'tree', 'tree', 'tree', 'tree', 'tree', 'shrub', 
         'shrub', 'herb', 'shrub', 'tree', 'tree', 'tree', 'shrub', 'shrub', 'tree', 'tree', 
         'shrub', 'tree', 'shrub', 'tree', 'tree', 'tree', 'tree', 'tree', 'tree', 'tree', 
         'tree', 'herb', 'tree', 'shrub', 'tree', 'tree', 'shrub', 'shrub', 'tree', 'tree', 
         'tree', 'tree', 'tree', 'herb', 'shrub', 'shrub', 'tree', 'shrub', 'tree']

# %%
for i, j in zip(df[df.lifeform == 'tree']['Species name'], trees):
    df.loc[df['Species name'] == i, 'lifeform'] = j

# %%
df.drop(df[df['Species name'] == 'Tessaria sericea'].index, inplace = True)

# %%
vines = ['vine', 'vine', 'vine', 'vine', 'vine', 'vine', 'vine', 'vine', 'vine', 'vine', 
         'vine', 'vine', 'vine', 'vine', 'vine', 'herb', 'vine', 'vine', 'vine', 'herb', 
         'vine', 'vine', 'vine', 'vine', 'vine', 'vine', 'vine', 'vine', 'vine', 'vine',
         'vine', 'vine', 'vine', 'vine', 'vine', 'herb', 'vine', 'vine', 'vine', 'vine',
         'vine', 'vine', 'vine', 'vine', 'vine', 'vine', 'vine', 'vine']

# %%
for i, j in zip(df[df.lifeform == 'vine']['Species name'], vines):
    df.loc[df['Species name'] == i, 'lifeform'] = j

# %%
df.drop(df[df['Species name'] == 'Janusia gracilis'].index, inplace = True)
df.drop(df[df['Species name'] == 'Matelea cordifolia'].index, inplace = True)

# %%
unknowns = ['herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'subshrub', 'herb', 
            'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'shrub', 'herb', 'herb', 
            'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'vine', 'herb', 'herb', 'tree', 
            'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 'herb', 
            'shrub', 'tree', 'grass', 'herb']

# %%
for i, j in zip(df[df.lifeform.isna()]['Species name'], unknowns):
    df.loc[df['Species name'] == i, 'lifeform'] = j

# %%
df.drop(df[df['Species name'] == 'Lappula redowskii'].index, inplace = True)
df.drop(df[df['Species name'] == 'Larrea divaricata'].index, inplace = True)
df.drop(df[df['Species name'] == 'Sibara virginica'].index, inplace = True)
df.drop(df[df['Species name'] == 'Camissonia claviformis'].index, inplace = True)
df.drop(df[df['Species name'] == 'Lotus humistratus'].index, inplace = True)
df.drop(df[df['Species name'] == 'Sapindus drummondii'].index, inplace = True)
df.drop(df[df['Species name'] == 'Chenopodium ambrosioides'].index, inplace = True)

# %%
df.reset_index(drop = True, inplace = True)

# %%
df['lifeform'].value_counts()
# Out:
# lifeform
# herb          542
# grass         160
# subshrub       99
# shrub          76
# vine           44
# tree           43
# cactus         37
# pterophyte     23
# succulent      13
# parasite        1
# Name: count, dtype: int64

# %% [markdown]
# # Elevation

# %%
def extract_elevation_ranges(text):
    """
    Extract elevation ranges from SW Field Guide text.

    Returns:
        pd.Series with:
        elev_ft_low, elev_ft_high, elev_m_low, elev_m_high
    """

    if pd.isna(text):
        return pd.Series([np.nan, np.nan, np.nan, np.nan])

    text = text.lower()

    # Pattern for ranges like: 2,500-4,000 ft (762-1219 m)
    range_pattern = re.search(
        r'(\d{1,3}(?:,\d{3})*)\s*-\s*(\d{1,3}(?:,\d{3})*)\s*ft\s*\(\s*(\d+)\s*-\s*(\d+)\s*m\s*\)',
        text
    )

    if range_pattern:
        ft_low, ft_high, m_low, m_high = range_pattern.groups()
        return pd.Series([
            int(ft_low.replace(',', '')),
            int(ft_high.replace(',', '')),
            int(m_low),
            int(m_high)
        ])

    # Pattern for "below X ft (Y m)"
    below_pattern = re.search(
        r'below\s*(\d{1,3}(?:,\d{3})*)\s*ft\s*\(\s*(\d+)\s*m\s*\)',
        text
    )

    if below_pattern:
        ft_high, m_high = below_pattern.groups()
        return pd.Series([
            0,
            int(ft_high.replace(',', '')),
            0,
            int(m_high)
        ])

    # If nothing matched
    return pd.Series([np.nan, np.nan, np.nan, np.nan])

# %%
df[['elev_ft_low', 'elev_ft_high', 'elev_m_low', 'elev_m_high']] = (df['SW Field Guide'].apply(extract_elevation_ranges))

# %%
def extract_fna_elevation_simple(text):
    """
    Extract elevation range in meters from FNA text.
    Handles:
      0-100 m
      500--2000 m
    """

    if pd.isna(text):
        return pd.Series([np.nan, np.nan])

    match = re.search(
        r';\s*(\d+)\s*-{1,2}\s*(\d+)\s*m\s*;',
        text
    )

    if match:
        low, high = match.groups()
        return pd.Series([int(low), int(high)])

    return pd.Series([np.nan, np.nan])

# %%
df[['fnaelev_m_low', 'fnaelev_m_high']] = (df['FNA'].apply(extract_fna_elevation_simple))

# %%
def extract_vpap_elevation(text):
    """
    Extract elevation range (meters) from VPAP descriptions.
    Avoids plant size measurements.
    """

    if pd.isna(text):
        return pd.Series([np.nan, np.nan])

    # Match elevation ranges in meters, allowing:
    #  - single or double dash
    #  - optional parenthetical extremes
    #  - optional feet after
    match = re.search(
        r'(\d+)\s*-{1,2}\s*(\d+)\s*(?:\([^)]*\))?\s*m\b',
        text
    )

    if match:
        low, high = match.groups()
        return pd.Series([int(low), int(high)])

    return pd.Series([np.nan, np.nan])

# %%
df[['vpap_elev_m_low', 'vpap_elev_m_high']] = (df['VPAP'].apply(extract_vpap_elevation))

# %%
df['low_elev_m'] = df[['elev_m_low', 'elev_m_high', 'fnaelev_m_low', 'fnaelev_m_high', 'vpap_elev_m_low', 'vpap_elev_m_high']].min(axis=1)
df['high_elev_m'] = df[['elev_m_low', 'elev_m_high', 'fnaelev_m_low', 'fnaelev_m_high', 'vpap_elev_m_low', 'vpap_elev_m_high']].max(axis=1)

# %%
df.drop(columns = ['elev_ft_low', 'elev_ft_high', 'elev_m_low', 'elev_m_high', 
                   'fnaelev_m_low', 'fnaelev_m_high', 'vpap_elev_m_low', 
                   'vpap_elev_m_high'], inplace = True)

# %%
df.loc[df['Species name'] == 'Parkinsonia florida', 'low_elev_m'] = 0
df.loc[df['Species name'] == 'Parkinsonia florida', 'high_elev_m'] = 1220

# %%
df.loc[df['Species name'] == 'Bromus berteroanus', 'low_elev_m'] = 0
df.loc[df['Species name'] == 'Bromus berteroanus', 'high_elev_m'] = 914

# %%
low_elev_m = [np.nan, 305, 0, np.nan, np.nan, np.nan, np.nan, 450, 0, 0, 
              0, np.nan, np.nan, 305, np.nan, 0, np.nan, np.nan, np.nan, 0, 
              0, 0, np.nan, np.nan, np.nan, 0, 0, 0, np.nan, 0, 
              0, 0, 0, 305, np.nan, np.nan, 305, 0, np.nan, 0, 
              0, np.nan, np.nan, 0, 0, 0, np.nan, 0, 0, np.nan, 
              np.nan, 0, np.nan, 305, 650, 0, 0, 0, 0, 0, 
              0, 0, np.nan, 0, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 
              np.nan, np.nan, np.nan, np.nan, np.nan, 0, np.nan, np.nan, 0, 
              np.nan, np.nan, np.nan, np.nan, 0, 0, np.nan, 1700, np.nan, 
              0, 500, 0, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 
              2600, np.nan, np.nan, np.nan, np.nan, np.nan, 0, np.nan, np.nan, np.nan, 
              np.nan, np.nan, 1700, 0, np.nan, 0, np.nan, np.nan, 0, 1067, 
              0, np.nan, np.nan, 1200, np.nan, 0, 0, np.nan, np.nan, np.nan, 
              np.nan, 0, 0, np.nan, np.nan, np.nan, np.nan, np.nan]

# %%
high_elev_m = [np.nan, 1524, 1219, np.nan, np.nan, np.nan, np.nan, 2100, 1524, 1067, 
               1600, np.nan, np.nan, 1067, np.nan, 5000, np.nan, np.nan, np.nan, 5000, 
               3000, 762, np.nan, np.nan, np.nan, 1067, 2000, 300, np.nan, 762, 
               547, 3050, 1000, 1829, np.nan, np.nan, 1524, 2134, np.nan, 1524, 
               1524, np.nan, np.nan, 610, 457, 198, np.nan, 1219, 1219, np.nan, 
               np.nan, 106, np.nan, 1219, 2450, 914, 2000, 1300, 1200, 1250, 
               762, 1000, np.nan, 1524, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 
               np.nan, np.nan, np.nan, np.nan, np.nan, 106, np.nan, np.nan, 2000, 
               np.nan, np.nan, np.nan, np.nan, 2000, 1067, np.nan, 2000, np.nan, 
               2000, 2000, 2000, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2000, 
               3400, np.nan, np.nan, np.nan, np.nan, np.nan, 2000, np.nan, np.nan, np.nan, 
               np.nan, np.nan, 3000, 1372, np.nan, 2000, np.nan, np.nan, 1219, 2591, 
               0, np.nan, np.nan, 2134, np.nan, 2000, 2000, np.nan, np.nan, np.nan, 
               np.nan, 2000, 2000, np.nan, np.nan, np.nan, np.nan, np.nan]

# %%
for i, j, k in zip(df[df.low_elev_m.isna()]['Species name'], low_elev_m, high_elev_m):
    df.loc[df['Species name'] == i, 'low_elev_m'] = j
    df.loc[df['Species name'] == i, 'high_elev_m'] = k

# %%
low = [np.nan, np.nan, 0, 0, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 
       np.nan, np.nan, np.nan, np.nan, np.nan, 0, np.nan, np.nan, 0, np.nan, 
       np.nan, np.nan, np.nan, 500, 0, np.nan, np.nan, 0, np.nan, np.nan, 
       np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 
       np.nan, np.nan, np.nan, np.nan, 200, np.nan, np.nan, np.nan, np.nan, np.nan, 
       np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 0, 1400, np.nan, 
       np.nan, np.nan, np.nan, 1000, 0, 0, np.nan, 0, np.nan, np.nan, 
       np.nan, 0, 0, np.nan, np.nan, np.nan, np.nan]

# %%
high = [np.nan, np.nan, 1800, 1800, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 
        np.nan, np.nan, np.nan, np.nan, np.nan, 2000, np.nan, np.nan, 1000, np.nan, 
        np.nan, np.nan, np.nan, 1500, 1800, np.nan, np.nan, 2000, np.nan, np.nan, 
        np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 
        np.nan, np.nan, np.nan, np.nan, 1000, np.nan, np.nan, np.nan, np.nan, np.nan, 
        np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 900, 2000, np.nan, 
        np.nan, np.nan, np.nan, 1800, 2000, 2000, np.nan, 2000, np.nan, np.nan, 
        np.nan, 2000, 2000, np.nan, np.nan, np.nan, np.nan]

# %%
for i, j, k in zip(df[df.low_elev_m.isna()]['Species name'], low, high):
    df.loc[df['Species name'] == i, 'low_elev_m'] = j
    df.loc[df['Species name'] == i, 'high_elev_m'] = k

# %%
df.loc[df['Species name'] == 'Petalonyx thurberi', 'low_elev_m'] = 0
df.loc[df['Species name'] == 'Petalonyx thurberi', 'high_elev_m'] = 1500
df.loc[df['Species name'] == 'Petalonyx linearis', 'low_elev_m'] = 0
df.loc[df['Species name'] == 'Petalonyx linearis', 'high_elev_m'] = 1000

# %% [markdown]
# # Checking for duplicates

# %%
dups = df[df['FNA'].notna() & df['FNA'].duplicated(keep=False)]

# %%
drops = ['Plumbago scandens', 'Muhlenbergia alopecuroides', 'Machaeranthera asteroides', 'Opuntia fulgida', 'Matthiola bicornis', 
         'Cenchrus ciliaris', 'Filago californica', 'Logfia californica', 'Filago depressa', 'Filago arizonica', 
         'Erigeron canadensis', 'Iva ambrosiaefolia', 'Enneapogon mollis', 'Pleuraphis mutica', 'Pleuraphis rigida', 
         'Trichloris crinita', 'Cheilanthes lindheimeri', 'Cheilanthes pringlei', 'Leptochloa fusca', 'Dinebra panicea', 
         'Leptochloa dubia', 'Boerhavia scandens', 'Machaeranthera pinnatifida', 'Machaeranthera arida', 'Schoenoplectus maritimus', 
         'Suaeda moquinii', 'Lesquerella purpurea']

# %%
for i in drops:
    df.drop(df[df['Species name'] == i].index, inplace = True)

# %%
dups = df[df['VPAP'].notna() & df['VPAP'].duplicated(keep=False)]

# %%
df.drop(279, inplace = True)

# %%
drops = ['Cynanchum arizonicum', 'Centaurium calycosum', 'Krameria grayi', 'Hyptis emoryi']

# %%
for i in drops:
    df.drop(df[df['Species name'] == i].index, inplace = True)

# %%
dups = df[df['SW Field Guide'].notna() & df['SW Field Guide'].duplicated(keep=False)]

# %%
dups.sort_values('SW Field Guide')
# Out:
#            Genus          Species  \
# 302      Eulobus     californicus
# 543   Camissonia      californica
# 299   Camissonia  chamaenerioides
# 301   Eremothera  chamaenerioides
# 478   Pennisetum         setaceum
# ..           ...              ...
# 311  Maurandella  antirrhiniflora
# 222     Acmispon          rigidus
# 458        Lotus          rigidus
# 745        Hopia           obtusa
# 477      Panicum          obtusum
#
#                                                    FNA VPAP  \
# 302                                                NaN  NaN
# 543                                                NaN  NaN
# 299                                                NaN  NaN
# 301                                                NaN  NaN
# 478  J.K. Wipff. Flora of North America Plants pere...  NaN
# ..                                                 ...  ...
# 311                                                NaN  NaN
# 222                                                NaN  NaN
# 458                                                NaN  NaN
# 745                                                NaN  NaN
# 477                                                NaN  NaN
#
#                                         SW Field Guide  \
# 302  Duration : Annual Nativity : Native Lifeform :...
# 543  Duration : Annual Nativity : Native Lifeform :...
# 299  Duration : Annual Nativity : Native Lifeform :...
# 301  Duration : Annual Nativity : Native Lifeform :...
# 478  FNA 2003 Common Name : crimson fountaingrass D...
# ..                                                 ...
# 311  Wiggins 1964, Kearney and Peebles 1969, McDoug...
# 222  Wiggins 1964, Welsh et al. 1993, Kearney and P...
# 458  Wiggins 1964, Welsh et al. 1993, Kearney and P...
# 745  Zuloaga et al. 2007, FNA 2003, Gould 1980 Comm...
# 477  Zuloaga et al. 2007, FNA 2003, Gould 1980 Comm...
#
#                     Species name          Family duration_consensus  \
# 302         Eulobus californicus      ONAGRACEAE             annual
# 543       Camissonia californica      ONAGRACEAE             annual
# 299   Camissonia chamaenerioides      ONAGRACEAE             annual
# 301   Eremothera chamaenerioides      ONAGRACEAE             annual
# 478          Pennisetum setaceum         POACEAE          perennial
# ..                           ...             ...                ...
# 311  Maurandella antirrhiniflora  PLANTAGINACEAE          perennial
# 222             Acmispon rigidus        FABACEAE          perennial
# 458                Lotus rigidus        FABACEAE          perennial
# 745                 Hopia obtusa         POACEAE          perennial
# 477              Panicum obtusum         POACEAE          perennial
#
#     nativity_sw  aquatic  lifeform  low_elev_m  high_elev_m
# 302      native        0      herb         0.0       1372.0
# 543      native        0      herb         0.0       1372.0
# 299      native        0      herb         0.0       1676.0
# 301      native        0      herb         0.0       1676.0
# 478  non-native        0     grass         0.0       1000.0
# ..          ...      ...       ...         ...          ...
# 311      native        0      vine       457.0       1981.0
# 222      native        0  subshrub         0.0       1676.0
# 458      native        0  subshrub         0.0       1676.0
# 745      native        0     grass       305.0       1829.0
# 477      native        1     grass       305.0       1829.0
#
# [83 rows x 13 columns]

# %% [markdown]
# # Saving dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1006 entries, 0 to 1037
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Genus               1006 non-null   object
#  1   Species             1006 non-null   object
#  2   FNA                 537 non-null    object
#  3   VPAP                207 non-null    object
#  4   SW Field Guide      919 non-null    object
#  5   Species name        1006 non-null   object
#  6   Family              1006 non-null   object
#  7   duration_consensus  1006 non-null   object
#  8   nativity_sw         1006 non-null   object
#  9   aquatic             1006 non-null   int64
#  10  lifeform            1006 non-null   object
#  11  low_elev_m          948 non-null    float64
#  12  high_elev_m         948 non-null    float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 110.0+ KB

# %%
df[(df.aquatic != 1) & (df.duration_consensus != 'annual') & (df.nativity_sw != 'non-native') & (df.low_elev_m < 1000)].shape
# Out:
# (389, 13)

# %%
df[(df.aquatic != 1) & (df.duration_consensus != 'annual') & (df.nativity_sw != 'non-native') & (df.low_elev_m < 1000)].lifeform.value_counts()
# Out:
# lifeform
# herb          108
# subshrub       86
# shrub          62
# grass          33
# cactus         32
# vine           19
# pterophyte     18
# tree           18
# succulent      12
# parasite        1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1006, 13)

# %%
#df.to_csv('plant_features.csv')
